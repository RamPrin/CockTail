# %%
import pandas as pd
cs = pd.read_csv("len_probs.csv", index_col=0)
cs.head()
# Out:
#    length  probability
# 0       4     0.319005
# 1       5     0.284215
# 2       3     0.162881
# 3       6     0.140311
# 4       7     0.040253

# %%
len_and_probs = cs.sort_values(by='length', ascending=True)
len_and_probs
# Out:
#     length  probability
# 9        1     0.000863
# 5        2     0.030190
# 2        3     0.162881
# 0        4     0.319005
# 1        5     0.284215
# 3        6     0.140311
# 4        7     0.040253
# 6        8     0.015095
# 7        9     0.004744
# 8       10     0.001869
# 10      11     0.000431
# 11      12     0.000144

# %%
cs.to_csv("pickup.csv")
